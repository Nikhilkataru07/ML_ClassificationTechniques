# %% [markdown]
# # Data Collection

# %%
#Importing Required Libraries
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sea

# %%
#dataset
df=pd.read_csv('dataset.csv')
df
# Out:
#        Termid   Regd No   Course Grade  CA_100  MTT_50  ETT_100  ETP_100  \
# 0      318192   1101776     KVY1     O    87.0    39.0     82.0     89.0
# 1      318192   1101776   KVY147    A+    87.0    47.0     65.0     85.0
# 2      318192   1101776   KVY148    B+    84.0    29.0     63.0     77.0
# 3      318192   1101776     KVY2    A+     NaN     NaN      NaN     82.0
# 4      318192   1101776     KVY3    A+    87.0    34.0     68.0     89.0
# 5      318192   1101776    KVY93    A+    97.0    33.0     75.0     96.0
# 6      318192   1101776    KVY94    A+     NaN     NaN      NaN     83.0
# 7      318192   1101776    KVY95     A    74.0    32.0     65.0     84.0
# 8      318192   1101776    KVY96    A+    82.0    38.0     58.0      NaN
# 9      318192   1101776    KVY97    B+    90.0    27.0     56.0     74.0
# 10     318192   1101776    KVY98    A+    87.0    34.0     76.0     81.0
# 11     318192   1101776   KVY991     O   100.0    39.0     93.0     97.0
# 12     518192   1103776     OLZ7    A+    87.0     NaN      NaN     69.0
# 13     418192   1104776    XPH10     F     0.0     NaN      NaN      0.0
# 14     418192   1104776    XPH11     E     0.0     NaN      0.0      NaN
# 15     418192   1104776     XPH8     E     0.0     0.0      0.0      NaN
# 16     418192   1104776     XPH9     E     0.0     NaN      NaN      0.0
# 17     518192   1105776    KYI12     A    89.0     NaN      NaN     64.0
# 18     218192   1107776    KNF20     C    57.0    15.0     36.0      NaN
# 19     218192   1107776    KNF21     D    40.0    32.0     30.0      NaN
# 20     218192   1107776    KNF22     E    72.0    14.0      6.0      NaN
# 21     218192   1107776    KNF23     C    60.0    30.0     36.0      NaN
# 22     218192   1107776    KNF24     E    55.0     NaN      NaN     15.0
# 23     218192   1107776    KNF25     A    82.0     NaN      NaN     80.0
# 24     218192   1107776    KNF26     D    50.0    25.0     19.0      NaN
# 25     218192   1107776    KNF27     C    52.0    22.0     43.0      NaN
# 26     218192   1107776    KNF28     B    47.0    25.0     63.0      NaN
# 27     218192   1108776    AUK29    B+    72.0    29.0     49.0      NaN
# 28     218192   1108776    AUK30     A    81.0     NaN      NaN     84.0
# 29     218192   1108776    AUK31    B+    64.0    35.0     68.0      NaN
# ...       ...       ...      ...   ...     ...     ...      ...      ...
# 65505  118192  15424776    IIN23    A+    82.0    44.0     73.0      NaN
# 65506  118192  15424776    IIN24     A    84.0     NaN      NaN     63.0
# 65507  118192  15424776    IIN25    A+    83.0     NaN      NaN     89.0
# 65508  118192  15424776    IIN28     B    73.0    33.0     66.0      NaN
# 65509  118192  15424776   IIN369    B+    78.0    23.0     63.0      NaN
# 65510  118192  15424776   IIN370    B+    84.0    32.0     43.0      NaN
# 65511  418192  15427776   CFB589     O     NaN     NaN      NaN     86.0
# 65512  118192  15428776  AYL1065     E     9.0    17.0     12.0      NaN
# 65513  118192  15428776   AYL179     E     9.0    19.0      0.0      NaN
# 65514  118192  15428776   AYL180     E    15.0     NaN      NaN     49.0
# 65515  118192  15428776   AYL181     E     0.0    10.0     10.0      NaN
# 65516  118192  15428776   AYL182     E    14.0    20.0     30.0      NaN
# 65517  118192  15428776   AYL312     C    80.0     8.0     40.0      NaN
# 65518  118192  15428776   AYL984     D    43.0    27.0     34.0      NaN
# 65519  118192  15431776  IIN1002     E    29.0    10.0     20.0      NaN
# 65520  118192  15431776   IIN145     E    41.0    25.0      6.0      NaN
# 65521  118192  15431776   IIN312     B    70.0    28.0     58.0      NaN
# 65522  118192  15431776   IIN385     B    51.0    15.0     58.0      NaN
# 65523  118192  15431776   IIN387     B    29.0    27.0     58.0      NaN
# 65524  118192  15431776   IIN396     B    47.0     NaN      NaN     58.0
# 65525  118192  15431776   IIN397     B    22.0    34.0     59.0      NaN
# 65526  118192  15431776   IIN452     E     9.0    13.0     10.0      NaN
# 65527  318192  15432776  ZVA1089     A    86.0     NaN      NaN     60.0
# 65528  318192  15432776   ZVA116    B+    77.0    23.0     49.0      NaN
# 65529  318192  15432776   ZVA163    A+    98.0    30.0     46.0      NaN
# 65530  318192  15432776   ZVA164     E    79.0     7.0     29.0      NaN
# 65531  318192  15432776   ZVA165     A    84.0     NaN      NaN     67.0
# 65532  318192  15432776   ZVA167    B+    69.0    20.0     70.0      NaN
# 65533  318192  15432776   ZVA168    A+    91.0     NaN      NaN     69.0
# 65534  318192  15432776    ZVA38     B    77.0    16.0     32.0      NaN
#
#        Course_Att                                           MHRDName  ...  \
# 0            88.0        Bachelor of Science (Honours) (Agriculture)  ...
# 1            82.0        Bachelor of Science (Honours) (Agriculture)  ...
# 2            76.0        Bachelor of Science (Honours) (Agriculture)  ...
# 3            74.0        Bachelor of Science (Honours) (Agriculture)  ...
# 4            76.0        Bachelor of Science (Honours) (Agriculture)  ...
# 5            80.0        Bachelor of Science (Honours) (Agriculture)  ...
# 6             NaN        Bachelor of Science (Honours) (Agriculture)  ...
# 7            77.0        Bachelor of Science (Honours) (Agriculture)  ...
# 8            75.0        Bachelor of Science (Honours) (Agriculture)  ...
# 9            73.0        Bachelor of Science (Honours) (Agriculture)  ...
# 10           80.0        Bachelor of Science (Honours) (Agriculture)  ...
# 11           74.0        Bachelor of Science (Honours) (Agriculture)  ...
# 12            NaN  Master of Computer Applications (2 Year progra...  ...
# 13            NaN   Bachelor of Technology in Mechanical Engineering  ...
# 14            0.0   Bachelor of Technology in Mechanical Engineering  ...
# 15            0.0   Bachelor of Technology in Mechanical Engineering  ...
# 16            0.0   Bachelor of Technology in Mechanical Engineering  ...
# 17            NaN  Integrated Bachelor of Technology - Master of ...  ...
# 18           85.0  Bachelor of Technology (Electrical and Electro...  ...
# 19           66.0  Bachelor of Technology (Electrical and Electro...  ...
# 20           77.0  Bachelor of Technology (Electrical and Electro...  ...
# 21           70.0  Bachelor of Technology (Electrical and Electro...  ...
# 22           98.0  Bachelor of Technology (Electrical and Electro...  ...
# 23          100.0  Bachelor of Technology (Electrical and Electro...  ...
# 24           88.0  Bachelor of Technology (Electrical and Electro...  ...
# 25           76.0  Bachelor of Technology (Electrical and Electro...  ...
# 26           82.0  Bachelor of Technology (Electrical and Electro...  ...
# 27           83.0         Bachelor of Technology (Civil Engineering)  ...
# 28           77.0         Bachelor of Technology (Civil Engineering)  ...
# 29           86.0         Bachelor of Technology (Civil Engineering)  ...
# ...           ...                                                ...  ...
# 65505        83.0  Bachelor of Technology (Electronics and Commun...  ...
# 65506        86.0  Bachelor of Technology (Electronics and Commun...  ...
# 65507        93.0  Bachelor of Technology (Electronics and Commun...  ...
# 65508        63.0  Bachelor of Technology (Electronics and Commun...  ...
# 65509        88.0  Bachelor of Technology (Electronics and Commun...  ...
# 65510        88.0  Bachelor of Technology (Electronics and Commun...  ...
# 65511         NaN  Bachelor of Technology (Computer Science and E...  ...
# 65512        76.0                  Bachelor of Computer Applications  ...
# 65513        78.0                  Bachelor of Computer Applications  ...
# 65514        66.0                  Bachelor of Computer Applications  ...
# 65515        72.0                  Bachelor of Computer Applications  ...
# 65516        83.0                  Bachelor of Computer Applications  ...
# 65517        80.0                  Bachelor of Computer Applications  ...
# 65518        77.0                  Bachelor of Computer Applications  ...
# 65519        80.0  Bachelor of Technology (Electronics and Commun...  ...
# 65520        84.0  Bachelor of Technology (Electronics and Commun...  ...
# 65521        80.0  Bachelor of Technology (Electronics and Commun...  ...
# 65522        85.0  Bachelor of Technology (Electronics and Commun...  ...
# 65523        85.0  Bachelor of Technology (Electronics and Commun...  ...
# 65524        75.0  Bachelor of Technology (Electronics and Commun...  ...
# 65525        83.0  Bachelor of Technology (Electronics and Commun...  ...
# 65526        86.0  Bachelor of Technology (Electronics and Commun...  ...
# 65527        88.0    Bachelor of Technology (Mechanical Engineering)  ...
# 65528        87.0    Bachelor of Technology (Mechanical Engineering)  ...
# 65529        84.0    Bachelor of Technology (Mechanical Engineering)  ...
# 65530        80.0    Bachelor of Technology (Mechanical Engineering)  ...
# 65531        75.0    Bachelor of Technology (Mechanical Engineering)  ...
# 65532        80.0    Bachelor of Technology (Mechanical Engineering)  ...
# 65533        72.0    Bachelor of Technology (Mechanical Engineering)  ...
# 65534        86.0    Bachelor of Technology (Mechanical Engineering)  ...
#
#        CA_3  CA_4  Height  Weight  ScholarType  Direction  Gender    Medium  \
# 0       1.0   0.0     181      65      Hostler      North  Female     Hindi
# 1       0.0   1.0     181      65      Hostler      North  Female     Hindi
# 2       3.0   5.0     181      65      Hostler      North  Female     Hindi
# 3       NaN   NaN     181      65      Hostler      North  Female     Hindi
# 4       2.0  17.0     181      65      Hostler      North  Female     Hindi
# 5       0.0   0.0     181      65      Hostler      North  Female     Hindi
# 6       NaN   NaN     181      65      Hostler      North  Female     Hindi
# 7       0.0   1.0     181      65      Hostler      North  Female     Hindi
# 8      15.0  46.0     181      65      Hostler      North  Female     Hindi
# 9       5.0  25.0     181      65      Hostler      North  Female     Hindi
# 10      0.0   2.0     181      65      Hostler      North  Female     Hindi
# 11      0.0   0.0     181      65      Hostler      North  Female     Hindi
# 12     16.0   1.0     170      66      Hostler       West    Male  Regional
# 13      0.0   0.0     163      67  Day Scholar       East    Male   English
# 14      0.0   0.0     163      67  Day Scholar       East    Male   English
# 15      0.0   0.0     163      67  Day Scholar       East    Male   English
# 16      0.0   0.0     163      67  Day Scholar       East    Male   English
# 17      4.0  18.0     155      75      Hostler      North  Female  Regional
# 18      3.0   8.0     158      70      Hostler       East    Male  Regional
# 19      0.0   0.0     158      70      Hostler       East    Male  Regional
# 20     10.0   9.0     158      70      Hostler       East    Male  Regional
# 21      4.0   3.0     158      70      Hostler       East    Male  Regional
# 22      2.0   1.0     158      70      Hostler       East    Male  Regional
# 23     32.0   0.0     158      70      Hostler       East    Male  Regional
# 24      7.0  13.0     158      70      Hostler       East    Male  Regional
# 25      0.0   0.0     158      70      Hostler       East    Male  Regional
# 26      6.0   9.0     158      70      Hostler       East    Male  Regional
# 27      5.0   0.0     158      63  Day Scholar       West  Female     Hindi
# 28      5.0  17.0     158      63  Day Scholar       West  Female     Hindi
# 29     17.0  11.0     158      63  Day Scholar       West  Female     Hindi
# ...     ...   ...     ...     ...          ...        ...     ...       ...
# 65505   7.0  24.0     162      62  Day Scholar      South  Female     Hindi
# 65506   3.0  13.0     162      62  Day Scholar      South  Female     Hindi
# 65507   4.0  26.0     162      62  Day Scholar      South  Female     Hindi
# 65508   0.0   9.0     162      62  Day Scholar      South  Female     Hindi
# 65509   3.0   0.0     162      62  Day Scholar      South  Female     Hindi
# 65510   9.0  23.0     162      62  Day Scholar      South  Female     Hindi
# 65511   NaN   NaN     165      56  Day Scholar      North    Male  Regional
# 65512   1.0   1.0     183      84  Day Scholar       East  Female     Hindi
# 65513   0.0   0.0     183      84  Day Scholar       East  Female     Hindi
# 65514  13.0   0.0     183      84  Day Scholar       East  Female     Hindi
# 65515   0.0   0.0     183      84  Day Scholar       East  Female     Hindi
# 65516   0.0   1.0     183      84  Day Scholar       East  Female     Hindi
# 65517   7.0   2.0     183      84  Day Scholar       East  Female     Hindi
# 65518   2.0   1.0     183      84  Day Scholar       East  Female     Hindi
# 65519   1.0   0.0     180      96      Hostler       East    Male   English
# 65520   4.0  16.0     180      96      Hostler       East    Male   English
# 65521  18.0   0.0     180      96      Hostler       East    Male   English
# 65522   3.0   2.0     180      96      Hostler       East    Male   English
# 65523   3.0   1.0     180      96      Hostler       East    Male   English
# 65524  12.0  23.0     180      96      Hostler       East    Male   English
# 65525   6.0   0.0     180      96      Hostler       East    Male   English
# 65526   0.0   0.0     180      96      Hostler       East    Male   English
# 65527   6.0   8.0     170      58  Day Scholar      South  Female     Hindi
# 65528   7.0   6.0     170      58  Day Scholar      South  Female     Hindi
# 65529   1.0  13.0     170      58  Day Scholar      South  Female     Hindi
# 65530  10.0  10.0     170      58  Day Scholar      South  Female     Hindi
# 65531  31.0   6.0     170      58  Day Scholar      South  Female     Hindi
# 65532   1.0   1.0     170      58  Day Scholar      South  Female     Hindi
# 65533   1.0   4.0     170      58  Day Scholar      South  Female     Hindi
# 65534   1.0   7.0     170      58  Day Scholar      South  Female     Hindi
#
#       CourseType ProgramType
# 0         Theory          UG
# 1         Theory          UG
# 2         Theory          UG
# 3      Practical          UG
# 4         Theory          UG
# 5         Theory          UG
# 6      Practical          UG
# 7         Theory          UG
# 8         Theory          UG
# 9         Theory          UG
# 10        Theory          UG
# 11        Theory          UG
# 12        Theory          PG
# 13        Theory          UG
# 14        Theory          UG
# 15        Theory          UG
# 16        Theory          UG
# 17        Theory          UG
# 18        Theory          UG
# 19        Theory          UG
# 20        Theory          UG
# 21        Theory          UG
# 22        Theory          UG
# 23        Theory          UG
# 24        Theory          UG
# 25        Theory          UG
# 26        Theory          UG
# 27        Theory          UG
# 28        Theory          UG
# 29        Theory          UG
# ...          ...         ...
# 65505     Theory          UG
# 65506     Theory          UG
# 65507     Theory          UG
# 65508     Theory          UG
# 65509     Theory          UG
# 65510     Theory          UG
# 65511  Practical          UG
# 65512     Theory          UG
# 65513     Theory          UG
# 65514     Theory          UG
# 65515     Theory          UG
# 65516     Theory          UG
# 65517     Theory          UG
# 65518     Theory          UG
# 65519     Theory          UG
# 65520     Theory          UG
# 65521     Theory          UG
# 65522     Theory          UG
# 65523     Theory          UG
# 65524     Theory          UG
# 65525     Theory          UG
# 65526     Theory          UG
# 65527     Theory          UG
# 65528     Theory          UG
# 65529     Theory          UG
# 65530     Theory          UG
# 65531     Theory          UG
# 65532     Theory          UG
# 65533     Theory          UG
# 65534     Theory          UG
#
# [65535 rows x 22 columns]

# %%
#rows and colums of the dataset
print('Rows :'+str(df.shape[0]))
print('Columns :'+str(df.shape[1]))
print(df['MHRDName'].value_counts())
# Out:
# Rows :65535
# Columns :22
# Bachelor of Science (Honours) (Agriculture)                                                                  7707
# Bachelor of Technology in Computer Science and Engineering (Big Data)                                        5493
# Bachelor of Technology (Computer Science and Engineering)                                                    4900
# Bachelor of Technology in Computer Science and Engineering (Android Application Development)                 4324
# Bachelor of Technology in Electronics and Communication Engineering (Internet of Things)                     3917
# Bachelor of Technology in Computer Science and Engineering (Data Science)                                    3705
# Bachelor of Technology (Mechanical Engineering)                                                              3238
# Bachelor of Technology (Electronics and Communication Engineering)                                           3209
# Bachelor of Technology (Civil Engineering)                                                                   3077
# Bachelor of Technology in Mechanical Engineering (Robotics and Mechatronics)                                 2692
# Bachelor of Computer Applications                                                                            1719
# Bachelor of Technology in Computer Science and Engineering (Machine Learning)                                1716
# Bachelor of Architecture                                                                                     1577
# Bachelor of Technology in Computer Science and Engineering (Full Stack Web Developer)                        1388
# Bachelor of Technology in Computer Science and Engineering (Cyber Security)                                  1365
# Diploma in Computer Science Engineering                                                                      1110
# Bachelor of Technology (Electrical and Electronics Engineering)                                               981
# Bachelor of Technology in Computer Science and Engineering (Cloud Computing)                                  882
# Bachelor of Technology (Biotechnology)                                                                        822
# Bachelor of Science (Honours) (Agriculture)                                                                   818
# Diploma in Mechanical Engineering                                                                             718
# Bachelor of Technology (Electrical Engineering)                                                               622
# Diploma in Civil Engineering                                                                                  621
# Bachelor of Technology (Automobile Engineering)                                                               577
# Bachelor of Technology (Aerospace Engineering)                                                                548
# Bachelor of Technology (Information Technology)                                                               488
# Bachelor of Science (Biotechnology)                                                                           468
# Integrated Bachelor of Technology - Master of Technology (Computer Science and Engineering)                   394
# Bachelor of Science (Forensic Science)                                                                        366
# Bachelor of Technology (Food Technology)                                                                      297
#                                                                                                              ...
# Master of Technology (Food Technology)                                                                          9
# Dual Degree Bachelor of Technology - Master of Technology (Mechanical Engineering)                              8
# Master of Technology (Geotechnical Engineering)                                                                 7
# Bachelor of Science (Honours) (Mathematics)                                                                     7
# Bachelor of Technology in Electrical Engineering                                                                6
# Bachelor of Science - Master of Science in Mathematics (Integrated)                                             6
# Bachelor of Computer Application-Master of Computer Applications(Integrated)                                    6
# Master of Science Ag. (Entomology)                                                                              6
# Bachelor of Technology in Biotechnology                                                                         6
# Master of Technology (Thermal Engineering)                                                                      5
# Master of Technology (Manufacturing Engineering)                                                                5
# Master of Sciences (Forensic Science)                                                                           5
# Master of Technology (Electronics and Communication Engineering)                                                5
# Dual Degree Bachelor of Technology (Computer Science and Engineering) - Master of Business Administration       4
# Integrated Bachelor of Science - Master of Science (Chemistry)                                                  4
# Master of Planning (Urban)                                                                                      4
# Bachelor of Technology in Automobile Engineering                                                                4
# Master of Science in Agriculture Horticulture (Fruit Science)                                                   4
# Bachelor of Technology in Information Technology                                                                4
# Master of Science Ag. (Plant Pathology)                                                                         3
# Master of Technology (Automobile Engineering)                                                                   3
# Master of Science in Agriculture (Soil Science and Agriculture Chemistry)                                       3
# Bachelor of Science (Honours) (Chemistry)                                                                       3
# Dual Degree Bachelor of Technology (Civil Engineering) - Master of Business Administration                      3
# Integrated Bachelor of Science - Master of Science (Botany)                                                     2
# Master of Science (Honours) (Biochemistry)                                                                      2
# Master of Technology (VLSI Design)                                                                              2
# Master of Science in Agriculture (Genetics and Plant Breeding)                                                  2
# Master of Technology (Power Systems)                                                                            2
# Master of Technology (Civil Engineering)                                                                        1
# Name: MHRDName, Length: 135, dtype: int64

# %%
#filtering the required data B.Tech (Cyber Security)
df=df[df['MHRDName']=="Bachelor of Technology in Computer Science and Engineering (Cyber Security)"]

# %%
#shape of the newly formed dataset
print("Rows :"+str(df.shape[0]))
print("Columns :"+str(df.shape[1]))
# Out:
# Rows :1365
# Columns :22

# %% [markdown]
# # Data Preprocessing

# %%
#displaying the features and its values
df.head(10)
# Out:
#      Termid  Regd No Course Grade  CA_100  MTT_50  ETT_100  ETP_100  \
# 47   218192  1113776  KHZ28    B+    57.0    17.0     56.0      NaN
# 48   218192  1113776  KHZ51     C    21.0    25.0     59.0      NaN
# 49   218192  1113776  KHZ52     A    96.0     NaN      NaN     56.0
# 50   218192  1113776  KHZ53    B+    54.0    30.0     69.0      NaN
# 51   218192  1113776  KHZ54     D    64.0     8.0     42.0      NaN
# 52   218192  1113776  KHZ55     A    89.0     NaN      NaN     59.0
# 53   218192  1113776  KHZ56     C    59.0    25.0     39.0      NaN
# 54   218192  1113776  KHZ57     B    50.0    25.0     65.0      NaN
# 55   218192  1113776  KHZ58     C    31.0    22.0     53.0      NaN
# 604  218192  1274776  KHZ28    A+    72.0    47.0     77.0      NaN
#
#      Course_Att                                           MHRDName  ...  CA_3  \
# 47         93.0  Bachelor of Technology in Computer Science and...  ...  12.0
# 48         83.0  Bachelor of Technology in Computer Science and...  ...   0.0
# 49         89.0  Bachelor of Technology in Computer Science and...  ...   5.0
# 50         67.0  Bachelor of Technology in Computer Science and...  ...   4.0
# 51         68.0  Bachelor of Technology in Computer Science and...  ...   8.0
# 52         97.0  Bachelor of Technology in Computer Science and...  ...   0.0
# 53         80.0  Bachelor of Technology in Computer Science and...  ...   0.0
# 54         67.0  Bachelor of Technology in Computer Science and...  ...  15.0
# 55         74.0  Bachelor of Technology in Computer Science and...  ...   3.0
# 604        93.0  Bachelor of Technology in Computer Science and...  ...   2.0
#
#      CA_4  Height  Weight  ScholarType  Direction  Gender   Medium CourseType  \
# 47    1.0     167      90  Day Scholar       East    Male    Hindi     Theory
# 48    1.0     167      90  Day Scholar       East    Male    Hindi     Theory
# 49   58.0     167      90  Day Scholar       East    Male    Hindi     Theory
# 50    8.0     167      90  Day Scholar       East    Male    Hindi     Theory
# 51    9.0     167      90  Day Scholar       East    Male    Hindi     Theory
# 52    0.0     167      90  Day Scholar       East    Male    Hindi     Theory
# 53    9.0     167      90  Day Scholar       East    Male    Hindi     Theory
# 54   25.0     167      90  Day Scholar       East    Male    Hindi     Theory
# 55    6.0     167      90  Day Scholar       East    Male    Hindi     Theory
# 604   7.0     177      96      Hostler      South  Female  English     Theory
#
#     ProgramType
# 47           UG
# 48           UG
# 49           UG
# 50           UG
# 51           UG
# 52           UG
# 53           UG
# 54           UG
# 55           UG
# 604          UG
#
# [10 rows x 22 columns]

# %%
#dropping the features that are not required as per the problem statement
df.drop(['Termid','Regd No','MHRDName', 'CA_1', 'CA_2','CA_3','CA_4','Height','Weight','ScholarType','Direction','CourseType','ProgramType','Medium' ],axis=1,inplace=True)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#dataset after dropping features
df.head(5)
# Out:
#    Course Grade  CA_100  MTT_50  ETT_100  ETP_100  Course_Att Gender
# 47  KHZ28    B+    57.0    17.0     56.0      NaN        93.0   Male
# 48  KHZ51     C    21.0    25.0     59.0      NaN        83.0   Male
# 49  KHZ52     A    96.0     NaN      NaN     56.0        89.0   Male
# 50  KHZ53    B+    54.0    30.0     69.0      NaN        67.0   Male
# 51  KHZ54     D    64.0     8.0     42.0      NaN        68.0   Male

# %%
#detailed Data
df.describe()
# Out:
#             CA_100       MTT_50      ETT_100     ETP_100   Course_Att
# count  1365.000000  1021.000000  1021.000000  344.000000  1365.000000
# mean     65.958974    28.214496    57.642507   69.270349    85.437363
# std      21.539905    10.318935    19.734873   19.919800    12.691174
# min       0.000000     0.000000     0.000000    0.000000     0.000000
# 25%      55.000000    23.000000    48.000000   63.000000    81.000000
# 50%      69.000000    29.000000    60.000000   73.000000    89.000000
# 75%      81.000000    35.000000    72.000000   83.000000    93.000000
# max     100.000000    49.000000    96.000000   98.000000   100.000000

# %%
#Mapping the feature 'grade' with numeric values so as to calculate the difficulty level of the course 
grade_map={'O':10,'A+':9,'A':8,'B+':7,'B':6,'C':5,'D':4,'E':3,'F':2}
df['Grade']=df['Grade'].map(grade_map)
df['Grade']
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 47        7
# 48        5
# 49        8
# 50        7
# 51        4
# 52        8
# 53        5
# 54        6
# 55        5
# 604       9
# 605       8
# 606       8
# 607       8
# 608       7
# 609       8
# 610       8
# 611       9
# 612       8
# 613       7
# 614       5
# 615       6
# 616       3
# 617       6
# 618       6
# 619       3
# 620       6
# 621       5
# 741       7
# 742       8
# 743       7
#          ..
# 60825     6
# 60826     4
# 62375     3
# 62376     8
# 62377     5
# 62378     6
# 62379     3
# 62380     6
# 62381     7
# 62382     6
# 62383     8
# 62384     5
# 62537     7
# 62538     8
# 62539     7
# 62540     7
# 62541     8
# 62542     6
# 62543     7
# 62544     6
# 62545    10
# 62546     7
# 64539     9
# 64540     9
# 64541     9
# 64542     8
# 64543     8
# 64544     7
# 64545     9
# 64546     7
# Name: Grade, Length: 1365, dtype: int64

# %%
#Label Encoder
#coverting the string type values
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
#converting the Course & Gender features values into numeric type
df['Course']=le.fit_transform(df['Course'])
df['Gender']=le.fit_transform(df['Gender'])
#display data
df.head(5)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#     Course  Grade  CA_100  MTT_50  ETT_100  ETP_100  Course_Att  Gender
# 47       3      7    57.0    17.0     56.0      NaN        93.0       1
# 48       8      5    21.0    25.0     59.0      NaN        83.0       1
# 49       9      8    96.0     NaN      NaN     56.0        89.0       1
# 50      10      7    54.0    30.0     69.0      NaN        67.0       1
# 51      11      4    64.0     8.0     42.0      NaN        68.0       1

# %%
#checking the null values that are present in the data
print(df.isnull().sum())
# Out:
# Course           0
# Grade            0
# CA_100           0
# MTT_50         344
# ETT_100        344
# ETP_100       1021
# Course_Att       0
# Gender           0
# dtype: int64

# %%
#Eliminating the null values
from sklearn.preprocessing import Imputer
#strategy used here is mean which is the average of all the values belonging to that particular feature
#we can use other strategies 'most_frequent' , 'median' as well
#im=Imputer(missing_values=np.nan,strategy='most-frequent',axis=0)
#im=Imputer(missing_values=np.nan,strategy='median',axis=0)

im=Imputer(missing_values=np.nan,strategy='mean',axis=0)
df['MTT_50']=im.fit_transform(df[['MTT_50']].values)
df['ETT_100']=im.fit_transform(df[['ETT_100']].values)
df['ETP_100']=im.fit_transform(df[['ETP_100']].values)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df.isnull()
# Out:
#        Course  Grade  CA_100  MTT_50  ETT_100  ETP_100  Course_Att  Gender
# 47      False  False   False   False    False    False       False   False
# 48      False  False   False   False    False    False       False   False
# 49      False  False   False   False    False    False       False   False
# 50      False  False   False   False    False    False       False   False
# 51      False  False   False   False    False    False       False   False
# 52      False  False   False   False    False    False       False   False
# 53      False  False   False   False    False    False       False   False
# 54      False  False   False   False    False    False       False   False
# 55      False  False   False   False    False    False       False   False
# 604     False  False   False   False    False    False       False   False
# 605     False  False   False   False    False    False       False   False
# 606     False  False   False   False    False    False       False   False
# 607     False  False   False   False    False    False       False   False
# 608     False  False   False   False    False    False       False   False
# 609     False  False   False   False    False    False       False   False
# 610     False  False   False   False    False    False       False   False
# 611     False  False   False   False    False    False       False   False
# 612     False  False   False   False    False    False       False   False
# 613     False  False   False   False    False    False       False   False
# 614     False  False   False   False    False    False       False   False
# 615     False  False   False   False    False    False       False   False
# 616     False  False   False   False    False    False       False   False
# 617     False  False   False   False    False    False       False   False
# 618     False  False   False   False    False    False       False   False
# 619     False  False   False   False    False    False       False   False
# 620     False  False   False   False    False    False       False   False
# 621     False  False   False   False    False    False       False   False
# 741     False  False   False   False    False    False       False   False
# 742     False  False   False   False    False    False       False   False
# 743     False  False   False   False    False    False       False   False
# ...       ...    ...     ...     ...      ...      ...         ...     ...
# 60825   False  False   False   False    False    False       False   False
# 60826   False  False   False   False    False    False       False   False
# 62375   False  False   False   False    False    False       False   False
# 62376   False  False   False   False    False    False       False   False
# 62377   False  False   False   False    False    False       False   False
# 62378   False  False   False   False    False    False       False   False
# 62379   False  False   False   False    False    False       False   False
# 62380   False  False   False   False    False    False       False   False
# 62381   False  False   False   False    False    False       False   False
# 62382   False  False   False   False    False    False       False   False
# 62383   False  False   False   False    False    False       False   False
# 62384   False  False   False   False    False    False       False   False
# 62537   False  False   False   False    False    False       False   False
# 62538   False  False   False   False    False    False       False   False
# 62539   False  False   False   False    False    False       False   False
# 62540   False  False   False   False    False    False       False   False
# 62541   False  False   False   False    False    False       False   False
# 62542   False  False   False   False    False    False       False   False
# 62543   False  False   False   False    False    False       False   False
# 62544   False  False   False   False    False    False       False   False
# 62545   False  False   False   False    False    False       False   False
# 62546   False  False   False   False    False    False       False   False
# 64539   False  False   False   False    False    False       False   False
# 64540   False  False   False   False    False    False       False   False
# 64541   False  False   False   False    False    False       False   False
# 64542   False  False   False   False    False    False       False   False
# 64543   False  False   False   False    False    False       False   False
# 64544   False  False   False   False    False    False       False   False
# 64545   False  False   False   False    False    False       False   False
# 64546   False  False   False   False    False    False       False   False
#
# [1365 rows x 8 columns]

# %%
#data after inserting new values
print(df.isnull().sum())
# Out:
# Course        0
# Grade         0
# CA_100        0
# MTT_50        0
# ETT_100       0
# ETP_100       0
# Course_Att    0
# Gender        0
# dtype: int64

# %%
#display data
df.head(5)
# Out:
#     Course  Grade  CA_100     MTT_50    ETT_100    ETP_100  Course_Att  Gender
# 47       3      7    57.0  17.000000  56.000000  69.270349        93.0       1
# 48       8      5    21.0  25.000000  59.000000  69.270349        83.0       1
# 49       9      8    96.0  28.214496  57.642507  56.000000        89.0       1
# 50      10      7    54.0  30.000000  69.000000  69.270349        67.0       1
# 51      11      4    64.0   8.000000  42.000000  69.270349        68.0       1

# %% [markdown]
# # Analysing Data

# %%
#number of male and female
sea.countplot(x="Gender", data=df)
df['Gender'].value_counts()
# Out:
# 0    693
# 1    672
# Name: Gender, dtype: int64

# %%
#grades comparison 
sea.countplot(x="Grade", data=df)
df['Grade'].value_counts()
# Out:
# 8     344
# 7     315
# 9     215
# 6     176
# 5     131
# 3      64
# 10     43
# 4      40
# 2      37
# Name: Grade, dtype: int64

# %%
#Grades and gender comparison
sea.countplot(x="Grade",hue='Gender',data=df)

# %%
df["MTT_50"].plot.hist()

# %%
df["ETT_100"].plot.hist()

# %%
df["ETP_100"].plot.hist()

# %%
df["CA_100"].plot.hist()

# %%
sea.countplot(x="Grade", hue="Gender", data=df)

# %%
#gender might be of no use for the required problem statement so dropping the feature 'gender'
#the features 'Course' , 'Grade' , 'CA_100' , 'Mtt_50' , 'ETT_100' , 'ETP_100' , 'Course_Att' are required for further processing
df.drop(['Gender'],axis=1,inplace=True)
#display data
df.tail(5)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#        Course  Grade  CA_100     MTT_50    ETT_100    ETP_100  Course_Att
# 64542       4      8    77.0  40.000000  63.000000  69.270349        92.0
# 64543       5      8    65.0  26.000000  74.000000  69.270349        93.0
# 64544       6      7    45.0  28.000000  69.000000  69.270349        95.0
# 64545      16      9    81.0  28.214496  57.642507  84.000000        94.0
# 64546      17      7    42.0  32.000000  53.000000  69.270349        97.0

# %% [markdown]
# # Train ,Test & Accuracy

# %%
#classifying the dataset into 'data' and 'target'
data=df.drop('Grade', axis = 1)
target=df['Grade']
#to arrange the data in a standard normal distribution
#it transforms the data in such a manner that it has mean as 0 and SD as 1
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
data=sc.fit_transform(data)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int32, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int32, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
#Splitting data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data,target,test_size=0.3,random_state=0)

# %% [markdown]
# # KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score

# %%
knn=KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train,y_train)
knn_pred=knn.predict(X_test)
print("KNeighborsClassifier")
print("Accuracy score :")
# comparing actual response values (y_test) with predicted response values (y_pred)
print(accuracy_score(y_test,knn_pred))
print("r2_score :")
print(r2_score(y_test,knn_pred))
# Out:
# KNeighborsClassifier
# Accuracy score :
# 0.7097560975609756
# r2_score :
# 0.8985571791119689

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC

# %%
model=SVC(C=10,kernel='rbf',gamma='auto')
model.fit(X_train,y_train)
svm_pred=model.predict(X_test)
from sklearn.metrics import accuracy_score
print("SVC")
print('Accuracy Score :')
# comparing actual response values (y_test) with predicted response values (y_pred)
print(accuracy_score(y_test,svm_pred))
print("r2_score :")
print(r2_score(y_test,svm_pred))
# Out:
# SVC
# Accuracy Score :
# 0.8268292682926829
# r2_score :
# 0.9384097158894097

# %% [markdown]
# # Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb=GaussianNB()
gnb.fit(X_train,y_train)
gnb_pred=gnb.predict(X_test)
print("GaussianNB")
print("Accuracy Score :")
# comparing actual response values (y_test) with predicted response values (y_pred)
print(accuracy_score(y_test,gnb_pred))
print("r2_score :")
print(r2_score(y_test,gnb_pred))
# Out:
# GaussianNB
# Accuracy Score :
# 0.4317073170731707
# r2_score :
# 0.4551071335157183

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
deci=DecisionTreeClassifier(criterion='gini')
deci.fit(X_train,y_train)
deci_pred=deci.predict(X_test)
print("DecisionTreeClassifier")
print("Accuracy Score :")
print(accuracy_score(y_test,deci_pred))
print("r2_score :")
print(r2_score(y_test,deci_pred))
# comparing actual response values (y_test) with predicted response values (y_pred)
# Out:
# DecisionTreeClassifier
# Accuracy Score :
# 0.6439024390243903
# r2_score :
# 0.8855145307120791

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
ran=RandomForestClassifier(n_estimators=100,criterion='gini',max_features=5)
ran.fit(X_train,y_train)
ran_pred=ran.predict(X_test)
# comparing actual response values (y_test) with predicted response values (y_pred)
print("RandomForestClassifier")
print("Accuracy Score :")
print(accuracy_score(y_test,ran_pred))
print("r2_score :")
print(r2_score(y_test,ran_pred))
# Out:
# RandomForestClassifier
# Accuracy Score :
# 0.7585365853658537
# r2_score :
# 0.9260916590672916

# %%
print("Comparing the  accuracy values attained from the  above models, SVC is best model for the given dataset with an accuracy_score of about 0.83")
# Out:
# Comparing the  accuracy values attained from the  above models, SVC is best model for the given dataset with an accuracy_score of about 0.83

# %% [markdown]
# # Difficulty level of the course

# %%
#calculating statistics
print("Calculating statistics of dataset provided in order to define the DIFFICULTY LEVEL of this course ..")
maximum_grade = np.max(target)
minimum_grade = np.min(target)
mean_grade= np.mean(target)
print("Maximum GRADE: "+str(maximum_grade))
print("Minimum GRADE: "+str(minimum_grade)) 
print("Mean GRADE: "+str(mean_grade))
diff=(mean_grade)*10
# Out:
# Calculating statistics of dataset provided in order to define the DIFFICULTY LEVEL of this course ..
# Maximum GRADE: 10
# Minimum GRADE: 2
# Mean GRADE: 6.92967032967033

# %%
#Setting difficulty levels
print("DIFFICULTY LEVEL of this course (B.Tech -Cyber Security) whose accuracy value is {} is :".format(diff))
level=['EASY','MEDIUM','HARD']
if diff<50:
    diff=level[0]
elif diff>50 and diff<75:
    diff=level[1]
else :
    diff=level[2]

print(diff)
# Out:
# DIFFICULTY LEVEL of this course (B.Tech -Cyber Security) whose accuracy value is 69.2967032967033 is :
# MEDIUM
